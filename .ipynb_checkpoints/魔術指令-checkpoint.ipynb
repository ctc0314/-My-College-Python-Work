# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# 魔術指令

# %%
plot([1,3,-5,2,4])

# %%
randn(8)
# Out:
# array([-0.36250478, -0.04854888, -0.51301621, -0.64689177, -0.99940996,
#        -1.54650359, -0.03227843,  1.84182207])

# %% [markdown]
# 隨機取變數

# %%
plot(randn(87))

# %%
plot([-2,7,16,23,41],[0,9,-3,4,9])

# %% [markdown]
# 連續畫座標([x,x,x,x],[y,y,y,y])
# =>(x,y),(x,y),
