# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3,4,5,6]
y=[2,8,4,6,7,8]

# %%
plt.plot(x,y)

# %%
np.random.randint(1,10)
# Out:
# 1

# %%
x=np.random.randn(100)

# %%
x
# Out:
# array([-1.25243609, -0.41695895, -0.34977718, -0.0120427 , -2.01493691,
#         0.28569958, -1.20854748, -0.84022194, -0.07657426,  0.51739102,
#         0.68122983,  0.22908967, -0.50118247, -0.51236066,  0.43205726,
#         0.61656081, -0.32115468,  0.82405478, -2.15762158, -1.59766761,
#        -0.01219103,  0.68872441,  0.01140624,  1.09176043,  0.28374769,
#         0.34934901,  1.28788979, -0.16064929, -0.40563681,  0.06418069,
#         0.60757158,  0.19877111, -0.88818356, -0.92683738, -0.68731239,
#        -0.80676941, -0.19928573,  1.06384216,  0.03614481,  0.75537927,
#        -0.57315416, -0.08043284, -0.94669316, -0.88050812, -1.43032721,
#         0.02438509,  0.86094428, -0.34189096, -1.62630582, -0.56265641,
#        -0.81990465,  0.17271045, -0.74553117,  0.97240821,  0.27920275,
#        -0.95708603,  0.07273185, -0.93344349, -0.08222916, -0.70323435,
#        -1.20988889,  0.35829569,  1.89819643,  1.22804415,  1.56060527,
#         0.70017518, -1.85232164,  0.6170817 ,  0.37774241,  0.73096869,
#        -1.43098973, -0.3961207 , -0.93404276, -0.45470053,  0.16878516,
#        -0.40599265, -0.57765346, -0.27395154,  0.88340681,  0.57167797,
#         1.06701893, -1.82673553, -2.36616675, -0.49841552,  0.9885528 ,
#        -0.37404033, -0.50602652,  1.74220215,  0.64581175,  0.96069449,
#         1.56465062, -1.27266241, -0.05233148, -0.98770918,  0.67524034,
#        -0.24546889,  1.68317095,  0.67817333,  0.28370656, -0.65947741])

# %%
x.mean()
# Out:
# -0.10565007425736525

# %%
x.std()
# Out:
# 0.9086468699229264

# %%
x
# Out:
# array([-1.25243609, -0.41695895, -0.34977718, -0.0120427 , -2.01493691,
#         0.28569958, -1.20854748, -0.84022194, -0.07657426,  0.51739102,
#         0.68122983,  0.22908967, -0.50118247, -0.51236066,  0.43205726,
#         0.61656081, -0.32115468,  0.82405478, -2.15762158, -1.59766761,
#        -0.01219103,  0.68872441,  0.01140624,  1.09176043,  0.28374769,
#         0.34934901,  1.28788979, -0.16064929, -0.40563681,  0.06418069,
#         0.60757158,  0.19877111, -0.88818356, -0.92683738, -0.68731239,
#        -0.80676941, -0.19928573,  1.06384216,  0.03614481,  0.75537927,
#        -0.57315416, -0.08043284, -0.94669316, -0.88050812, -1.43032721,
#         0.02438509,  0.86094428, -0.34189096, -1.62630582, -0.56265641,
#        -0.81990465,  0.17271045, -0.74553117,  0.97240821,  0.27920275,
#        -0.95708603,  0.07273185, -0.93344349, -0.08222916, -0.70323435,
#        -1.20988889,  0.35829569,  1.89819643,  1.22804415,  1.56060527,
#         0.70017518, -1.85232164,  0.6170817 ,  0.37774241,  0.73096869,
#        -1.43098973, -0.3961207 , -0.93404276, -0.45470053,  0.16878516,
#        -0.40599265, -0.57765346, -0.27395154,  0.88340681,  0.57167797,
#         1.06701893, -1.82673553, -2.36616675, -0.49841552,  0.9885528 ,
#        -0.37404033, -0.50602652,  1.74220215,  0.64581175,  0.96069449,
#         1.56465062, -1.27266241, -0.05233148, -0.98770918,  0.67524034,
#        -0.24546889,  1.68317095,  0.67817333,  0.28370656, -0.65947741])

# %%
plt.plot(x)

# %%
x=x+37

# %%
x=x-37

# %%
x = 5*x +37

# %%
x.mean()
# Out:
# 36.47174962871318

# %%
x.std()
# Out:
# 4.543234349614631

# %%
x = np.linspace(0,10,200)

# %%
y = np.sin(x) + 0.8*x

# %%
plt.plot(x,y)

# %%
y = np.sin(x) + 0.8*x + 0.4*np.random.randn(200)

# %%
plt.scatter(x,y)
