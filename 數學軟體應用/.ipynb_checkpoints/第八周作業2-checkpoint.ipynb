# %% [markdown]
# # 地政事務所轄區圖

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
column_names = 'OBJECTID,A_CODE,C_CODE,AGENCY,CITY,C_NAME,SHAPE_LENG,SHAPE_LE_1,SHAPE_AREA,SHAPE_LEN'.split(',')

# %%
df1 = pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=13043&md5_url=ee51a673ab65becf6ecbc91347ce8794',names=column_names)

# %%
df1
# Out:
#    OBJECTID A_CODE C_CODE AGENCY                                       CITY  \
# 0       205     XA      X     澎湖  澎湖縣馬公市、澎湖縣湖西鄉、澎湖縣白沙鄉、澎湖縣西嶼鄉、澎湖縣望安鄉、澎湖縣七美鄉
# 1       205     XA      X     澎湖  澎湖縣馬公市、澎湖縣湖西鄉、澎湖縣白沙鄉、澎湖縣西嶼鄉、澎湖縣望安鄉、澎湖縣七美鄉
# 2         5     WA      W     金門  金門縣金湖鎮、金門縣金沙鎮、金門縣金城鎮、金門縣金寧鄉、金門縣烈嶼鄉、金門縣烏坵鄉
# 3         1     ZA      Z     連江                連江縣南竿鄉、連江縣北竿鄉、連江縣莒光鄉、連江縣東引鄉
#
#   C_NAME     SHAPE_LENG     SHAPE_LE_1    SHAPE_AREA      SHAPE_LEN
# 0    澎湖縣  583629.611522  583629.611522  1.351646e+08  583629.611522
# 1    澎湖縣  583629.611522  583629.611522  1.351646e+08  583629.611522
# 2    金門縣  142798.019757  142798.019757  1.847008e+08  142798.019757
# 3    連江縣  127904.655540  127904.655540  2.478512e+07  127904.655540

# %%
df2 = pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=13047&md5_url=d7a421fcc3f5d5c83986700aae605beb',names=column_names)

# %%
df2
# Out:
#      OBJECTID A_CODE C_CODE AGENCY  \
# 0           3     RF      R     歸仁
# 1           3     RF      R     歸仁
# 2           4     RG      R     玉井
# 3           5     RH      R     永康
# 4          12     EL      E     大寮
# 5          13     TA      T     屏東
# 6           6     EF      E     岡山
# 7           7     EG      E     鳳山
# 8           8     EH      E     旗山
# 9          14     TB      T     里港
# 10         15     TC      T     潮州
# 11          1     RD      R     佳里
# 12          9     EI      E     仁武
# 13         10     EJ      E     路竹
# 14         11     EK      E     美濃
# 15          2     RE      R     新化
# 16         16     TD      T     東港
# 17         17     TE      T     恒春
# 18         18     TF      T     枋寮
# 19         19     UA      U     花蓮
# 20         20     UB      U     鳳林
# 21         21     UC      U     玉里
# 22         22     VA      V     臺東
# 23         23     VB      V     成功
# 24         24     VC      V     關山
# ...

# %%
df3 = pd.read_csv('http://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=60800EC7-60DC-41D2-A7D6-3B1F1C69413B',names=column_names)

# %%
df3
# Out:
#                                             OBJECTID  A_CODE  C_CODE  AGENCY  \
# 0  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...     NaN     NaN     NaN
#
#    CITY  C_NAME  SHAPE_LENG  SHAPE_LE_1  SHAPE_AREA  SHAPE_LEN
# 0   NaN     NaN         NaN         NaN         NaN        NaN
