# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3,4,5,6]
y=[2,8,4,6,7,8]

# %%
plt.plot(x,y)

# %%
np.random.randint(1,10)
# Out:
# 1

# %%
x=np.random.randn(100)

# %%
x
# Out:
# array([-0.74916124, -1.7941023 , -2.64490063, -0.8399893 , -0.51572358,
#        -0.94456325, -0.47697048, -1.61892598, -0.23051994, -0.50976407,
#        -1.65616153, -2.10382676,  0.31943494,  1.51944565, -0.90036388,
#         0.94203944, -0.50295259,  1.47787963, -0.77261603, -1.1876672 ,
#         1.35519167,  1.45517614,  1.77502154,  0.29531322, -1.15155016,
#        -0.04970225, -0.81844993,  0.89377479,  0.33862412, -0.12847623,
#         2.22387645, -0.51314806,  0.28443993, -1.32817669,  0.70152146,
#         0.99991996,  0.62567787,  0.15572971,  0.28289914,  0.14354723,
#        -0.19741708,  1.64828645,  0.65629828, -0.17173136,  1.35190989,
#         0.13793119, -1.52444223, -0.46214613, -1.21732294,  0.90802023,
#         0.15799907,  1.65674379,  0.19435441, -2.69790661, -0.08312594,
#        -0.46172015,  1.47026094, -0.81523519, -0.70669668,  0.89600089,
#        -1.94872974,  1.670915  ,  0.57708388,  0.31062805,  0.63722313,
#         1.02927814,  1.94875161,  0.25558034,  1.65048276, -1.11989796,
#         0.40356826,  0.59093433,  0.27747472,  0.32934376,  0.12143148,
#        -0.22324994,  1.00388261, -1.79011339, -0.76391274, -0.38307293,
#         1.34399165,  1.09359064,  0.11989428, -0.64529338,  2.20884165,
#        -0.57442699, -0.16833967, -0.00927621, -0.86360218,  1.3967338 ,
#         0.59394623, -0.50953417,  0.84313611,  0.45547664,  1.81498959,
#         0.58162601,  1.15532323, -0.55072373,  0.82952655, -0.80804281])

# %%
x.mean()
# Out:
# -0.03571982505351102

# %%
plt.plot(x)

# %%
x=x+37

# %%
x=x-37

# %%
x = 5*x +37

# %%
x.mean()
# Out:
# 36.82140087473244

# %%
x.std()
# Out:
# 4.981062785210317

# %%
x = np.linspace(0,10,200)

# %%
y = np.sin(x) + 0.8*x

# %%
plt.plot(x,y)

# %%
y = np.sin(x) + 0.8*x + 0.4*np.random.randn(200)

# %%
plt.scatter(x,y)
