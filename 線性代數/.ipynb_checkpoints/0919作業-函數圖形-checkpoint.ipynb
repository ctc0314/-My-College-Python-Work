# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import sympy as sp
import numpy as np

# %%
x = np.linspace(0,100,10000)

# %%
y = np.sin(2*(x**2))

# %%
y
# Out:
# array([ 0.00000000e+00,  2.00040005e-04,  8.00159939e-04, ...,
#        -8.89224586e-01,  2.35215321e-01,  5.81984762e-01])

# %%
np.sin(2*(x**(1/2)))
# Out:
# array([0.        , 0.19867913, 0.27910011, ..., 0.91212714, 0.91253666,
#        0.91294525])

# %%
np.sin(x)
# Out:
# array([ 0.        ,  0.01000083,  0.02000067, ..., -0.5235113 ,
#        -0.51496423, -0.50636564])

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot(x,y)
