# %%
#python註解加#號

# %%
#切換到markddown模式整欄加註解

# %%
#ctrl+m快速切換markdown模式

# %% [markdown]
# ### 做超連結
#
# [Fb](https://www.facebook.com/)

# %% [markdown]
# 插入圖片
# ![minions.jpg](attachment:minions.jpg)

# %% [markdown]
# ![minions.jpg](attachment:minions.jpg)
